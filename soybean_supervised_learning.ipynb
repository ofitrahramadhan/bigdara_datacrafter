# %% [markdown]
# # Big Data Application: Modeling for Crop Yield Estimation

# %% [markdown]
# This jupyter notebook is addressed for creating model that can estimate crop yield in North Dakota, United States. The detail workflow of this project can be seen in [here](https://drive.google.com/file/d/1u3jHTnLqoxMca7SRzgnvGjP-iBvfTnls/view?usp=sharing).

# %% [markdown]
# ## 0. Install & Load Packages

# %%
#install packages
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.23.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (68.1.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.24.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (13.5.3)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (0.0.7)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.0)

# %%
#load packages

import pandas as pd
from sklearn.preprocessing import StandardScaler

#packages for manipulating dataframe
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import sklearn

#packages for machine learning
##train-test-split
from sklearn.model_selection import train_test_split, GridSearchCV, validation_curve

##method 1: Linear Regression (LR)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score

##method 2: Random Forest Regressor (RF)
import rfpimp
from sklearn.ensemble import RandomForestRegressor

##method 3: Gradient Boosting Regressor (XGB)
import xgboost
from xgboost import XGBRegressor

##method 4: Artificial Neural Network (ANN)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

##cross validation

##evaluation metrics (R2 and RMSE)
from sklearn.metrics import r2_score, mean_squared_error

#data visualization
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %% [markdown]
# ## 1. Load & Cleaning Data

# %%
#load data
soybean_2018 = pd.read_csv('https://www.dropbox.com/scl/fi/ixibqk9pyuehwvoz7mr1h/2018_County_Summary_Merged.csv?rlkey=wueodqdvzsht5or4eftwdd3ys&dl=1')
soybean_2019 = pd.read_csv('https://www.dropbox.com/scl/fi/x3oiqrikr0xagqrh5tiqu/2019_County_Summary_Merged.csv?rlkey=zr5wru8sg5iybp43lnjf7ls5a&dl=1')
soybean_2020 = pd.read_csv('https://www.dropbox.com/scl/fi/m4r74ydgw3yno93nakagl/2020_County_Summary_Merged.csv?rlkey=kmd8bozo9z9jxznoa775gg33z&dl=1')
soybean_2021 = pd.read_csv('https://www.dropbox.com/scl/fi/2vmvsyjloz9hvzejtdez4/2021_County_Summary_Merged.csv?rlkey=ossgr4x3fvzgebhqprchntt2f&dl=1')
soybean_2022 = pd.read_csv('https://www.dropbox.com/scl/fi/x61224yvwtq4idnqphwjy/2022_County_Summary_Merged.csv?rlkey=s3zm9ooap8pjqom3jr0aklc6t&dl=1')
soybean_2023 = pd.read_csv('https://www.dropbox.com/scl/fi/zrjnmeqysrokfsua24hb3/2023_County_Summary_Merged.csv?rlkey=jb4w1pt295zeagbvgm7c2t7pk&dl=1')

# %%
soybean_list = [soybean_2018, soybean_2019, soybean_2020, soybean_2021, soybean_2022, soybean_2023]
soybean_df = pd.concat(soybean_list)
soybean_df = soybean_df.drop(['NAME','GEOID'], axis=1)
soybean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316 entries, 0 to 52
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LST_DAY    316 non-null    float64
#  1   SMS_AM     316 non-null    float64
#  2   SAR        316 non-null    float64
#  3   PA         316 non-null    float64
#  4   NDVI       316 non-null    float64
#  5   ET         316 non-null    float64
#  6   LST_NIGHT  316 non-null    float64
#  7   PAR        316 non-null    float64
#  8   SMS_PM     316 non-null    float64
#  9   YIELD      316 non-null    float64
# dtypes: float64(10)
# memory usage: 27.2 KB

# %%
soybean_df.YIELD.hist()
# Out:
# <Axes: >

# %%
# Correlation coefficients
correlation_matrix = soybean_df.corr()

plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))
plt.matshow(soybean_df.corr(), fignum=f.number,cmap='bwr')
plt.xticks(range(soybean_df.shape[1]), soybean_df.columns, fontsize=14, rotation=90)
plt.yticks(range(soybean_df.shape[1]), soybean_df.columns, fontsize=14)

for i in range(soybean_df.shape[1]):
    for j in range(soybean_df.shape[1]):
        plt.text(j, i, f'{correlation_matrix.iloc[i, j]:.2f}', ha='center', va='center', fontsize=12, color='black')

cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)

plt.savefig('correlation_matrix_soybean.png', bbox_inches='tight')

plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ## 2.1 Train & Test Data Split

# %%
#split the dataset
X = soybean_df.drop('YIELD', axis=1)
y = soybean_df['YIELD']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=100)

# %% [markdown]
# ## 2.2 Train & Test Data Standarderlized

# %%
def standardize_columns(file_name, columns_to_standardize):
    scaler = StandardScaler()

    df = file_name
    df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])
    return df

def standardize_series(series):
    scaler = StandardScaler()
    series = scaler.fit_transform(series.values.reshape(-1, 1)).flatten()
    return series
    
X_columns = ['LST_DAY','SMS_AM','SAR','PA','NDVI','ET','LST_NIGHT','PAR','SMS_PM']
y_columns = ['YIELD']

X_train = standardize_columns(X_train, X_columns)
X_test = standardize_columns(X_test, X_columns)

y_train = standardize_series(y_train)
y_test = standardize_series(y_test)

# %% [markdown]
# ## 3. Model Training and Parameter Tuning

# %% [markdown]
# ### 3.1. Linear Regression (LR)

# %%
model_lr = LinearRegression()

# Cross validation
scores = cross_val_score(model_lr, X, y, cv=5, scoring='neg_mean_squared_error')

mean_mse = np.mean(scores)
std_mse = np.std(scores)

print(f'Mean MSE: {mean_mse}')
print(f'Standard Deviation of MSE: {std_mse}')
# Out:
# Mean MSE: -13.488789923248467
# Standard Deviation of MSE: 1.0995120405175056

# %%
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 3.2. Random Forest Regressor (RF)

# %%
# values of max_depth and min_samples_split
hyperparameters = {'max_depth':[3,5,10,20,30], 'min_samples_split':[2,4,6,8,10]}


randomState_dt = 10000
model_rf = RandomForestRegressor(random_state=randomState_dt)

# cv=5 by default, which means 5-fold cross-validation
clf = GridSearchCV(model_rf, hyperparameters)

clf.fit(X_train, y_train)

# we can query the best parameter value and its accuracy score
print ("The best parameter value is: ")
print (clf.best_params_)
print ("The best score is: ")
print (clf.best_score_)
# Out:
# The best parameter value is:
# {'max_depth': 20, 'min_samples_split': 6}
# The best score is:
# 0.8099771144161796

# %%
# Train the final RF
rf_final = RandomForestRegressor(max_depth=clf.best_params_['max_depth'], min_samples_split=clf.best_params_['min_samples_split'], random_state=randomState_dt)
rf_final.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=20, min_samples_split=6, random_state=10000)

# %% [markdown]
# ### 3.3. Gradient Boosting Regressor (XGB)

# %%
import warnings

# 设置忽略 FutureWarning 类型的警告
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# model_xgb =
# soybean_df

# values of max_depth and min_samples_split
hyperparameters = {'max_depth':[2,4,6,8,10], 'n_estimators':[4,8,12,16,20]}

randomState_xgb = 125
xgb = XGBRegressor(random_state=randomState_xgb)

# cv=5 by default, which means 5-fold cross-validation
gscv_xgb = GridSearchCV(xgb, hyperparameters)

gscv_xgb.fit(X_train, y_train)

# we can query the best parameter value and its accuracy score
print ("The best parameter value is: ")
print (gscv_xgb.best_params_)
print ("The best score is: ")
print (gscv_xgb.best_score_)
# Out:
# The best parameter value is:
# {'max_depth': 2, 'n_estimators': 20}
# The best score is:
# 0.8022211096828226

# %% [markdown]
# ### 3.4. Artificial Neural Network (ANN)

# %%
model_ann = keras.Sequential([
    layers.Input(shape=(9,)),  # Input layer
    layers.Dense(128, activation='relu'),  # Hidden layer with ReLU activation
    layers.Dropout(0.5),  # Dropout layer for regularization
    layers.Dense(64, activation='relu'),  # Additional hidden layer
    layers.Dropout(0.3),  # Another dropout layer
    layers.Dense(1)  # Output layer
])

#measuring the training with certain metrics
model_ann.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# %%
#train the model
model_ann.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.0000e+00 - loss: 1.1973 - val_accuracy: 0.0000e+00 - val_loss: 0.3962
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.5143 - val_accuracy: 0.0000e+00 - val_loss: 0.2785
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.4752 - val_accuracy: 0.0000e+00 - val_loss: 0.2803
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0000e+00 - loss: 0.3852 - val_accuracy: 0.0000e+00 - val_loss: 0.2646
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.3439 - val_accuracy: 0.0000e+00 - val_loss: 0.2379
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.3187 - val_accuracy: 0.0000e+00 - val_loss: 0.2123
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.3476 - val_accuracy: 0.0000e+00 - val_loss: 0.2140
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.3062 - val_accuracy: 0.0000e+00 - val_loss: 0.2058
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.3034 - val_accuracy: 0.0000e+00 - val_loss: 0.1991
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.3048 - val_accuracy: 0.0000e+00 - val_loss: 0.1928
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.3098 - val_accuracy: 0.0000e+00 - val_loss: 0.1992
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.3086 - val_accuracy: 0.0000e+00 - val_loss: 0.2050
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2996 - val_accuracy: 0.0000e+00 - val_loss: 0.1994
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.2719 - val_accuracy: 0.0000e+00 - val_loss: 0.1929
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2380 - val_accuracy: 0.0000e+00 - val_loss: 0.1780
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2506 - val_accuracy: 0.0000e+00 - val_loss: 0.1739
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.3132 - val_accuracy: 0.0000e+00 - val_loss: 0.1727
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2895 - val_accuracy: 0.0000e+00 - val_loss: 0.1996
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2628 - val_accuracy: 0.0000e+00 - val_loss: 0.2088
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2594 - val_accuracy: 0.0000e+00 - val_loss: 0.1956
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2554 - val_accuracy: 0.0000e+00 - val_loss: 0.1825
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2618 - val_accuracy: 0.0000e+00 - val_loss: 0.1794
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2163 - val_accuracy: 0.0000e+00 - val_loss: 0.1912
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2662 - val_accuracy: 0.0000e+00 - val_loss: 0.1901
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2752 - val_accuracy: 0.0000e+00 - val_loss: 0.1904
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2499 - val_accuracy: 0.0000e+00 - val_loss: 0.2024
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2284 - val_accuracy: 0.0000e+00 - val_loss: 0.1803
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2327 - val_accuracy: 0.0000e+00 - val_loss: 0.1837
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2400 - val_accuracy: 0.0000e+00 - val_loss: 0.1865
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2400 - val_accuracy: 0.0000e+00 - val_loss: 0.1769
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2134 - val_accuracy: 0.0000e+00 - val_loss: 0.1760
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1897 - val_accuracy: 0.0000e+00 - val_loss: 0.1871
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2302 - val_accuracy: 0.0000e+00 - val_loss: 0.1789
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2525 - val_accuracy: 0.0000e+00 - val_loss: 0.1860
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2763 - val_accuracy: 0.0000e+00 - val_loss: 0.1907
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.2532 - val_accuracy: 0.0000e+00 - val_loss: 0.2180
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2331 - val_accuracy: 0.0000e+00 - val_loss: 0.2186
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2201 - val_accuracy: 0.0000e+00 - val_loss: 0.2053
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2287 - val_accuracy: 0.0000e+00 - val_loss: 0.1815
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.1999 - val_accuracy: 0.0000e+00 - val_loss: 0.1789
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2414 - val_accuracy: 0.0000e+00 - val_loss: 0.1983
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.1944 - val_accuracy: 0.0000e+00 - val_loss: 0.1923
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2238 - val_accuracy: 0.0000e+00 - val_loss: 0.1862
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2097 - val_accuracy: 0.0000e+00 - val_loss: 0.1900
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1789 - val_accuracy: 0.0000e+00 - val_loss: 0.1856
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2250 - val_accuracy: 0.0000e+00 - val_loss: 0.1775
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1840 - val_accuracy: 0.0000e+00 - val_loss: 0.1738
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2327 - val_accuracy: 0.0000e+00 - val_loss: 0.1995
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2175 - val_accuracy: 0.0000e+00 - val_loss: 0.2105
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1987 - val_accuracy: 0.0000e+00 - val_loss: 0.1927
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.1870 - val_accuracy: 0.0000e+00 - val_loss: 0.1691
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2126 - val_accuracy: 0.0000e+00 - val_loss: 0.1654
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2074 - val_accuracy: 0.0000e+00 - val_loss: 0.1761
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.1859 - val_accuracy: 0.0000e+00 - val_loss: 0.2040
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2185 - val_accuracy: 0.0000e+00 - val_loss: 0.2051
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2211 - val_accuracy: 0.0000e+00 - val_loss: 0.1902
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2167 - val_accuracy: 0.0000e+00 - val_loss: 0.1763
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1983 - val_accuracy: 0.0000e+00 - val_loss: 0.1895
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2267 - val_accuracy: 0.0000e+00 - val_loss: 0.1905
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2238 - val_accuracy: 0.0000e+00 - val_loss: 0.1833
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1684 - val_accuracy: 0.0000e+00 - val_loss: 0.1852
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2130 - val_accuracy: 0.0000e+00 - val_loss: 0.1879
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.2141 - val_accuracy: 0.0000e+00 - val_loss: 0.1804
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2148 - val_accuracy: 0.0000e+00 - val_loss: 0.1828
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1892 - val_accuracy: 0.0000e+00 - val_loss: 0.1797
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1889 - val_accuracy: 0.0000e+00 - val_loss: 0.1883
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.1917 - val_accuracy: 0.0000e+00 - val_loss: 0.1981
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1702 - val_accuracy: 0.0000e+00 - val_loss: 0.1887
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.1880 - val_accuracy: 0.0000e+00 - val_loss: 0.1935
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1855 - val_accuracy: 0.0000e+00 - val_loss: 0.1977
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1858 - val_accuracy: 0.0000e+00 - val_loss: 0.1966
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1853 - val_accuracy: 0.0000e+00 - val_loss: 0.2266
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1931 - val_accuracy: 0.0000e+00 - val_loss: 0.2162
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1777 - val_accuracy: 0.0000e+00 - val_loss: 0.1897
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1872 - val_accuracy: 0.0000e+00 - val_loss: 0.1756
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.2032 - val_accuracy: 0.0000e+00 - val_loss: 0.1889
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1396 - val_accuracy: 0.0000e+00 - val_loss: 0.2052
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2133 - val_accuracy: 0.0000e+00 - val_loss: 0.2017
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1687 - val_accuracy: 0.0000e+00 - val_loss: 0.2009
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2001 - val_accuracy: 0.0000e+00 - val_loss: 0.2088
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1842 - val_accuracy: 0.0000e+00 - val_loss: 0.1966
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1724 - val_accuracy: 0.0000e+00 - val_loss: 0.1782
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1816 - val_accuracy: 0.0000e+00 - val_loss: 0.1858
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2140 - val_accuracy: 0.0000e+00 - val_loss: 0.2160
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.2085 - val_accuracy: 0.0000e+00 - val_loss: 0.2158
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1841 - val_accuracy: 0.0000e+00 - val_loss: 0.1930
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1707 - val_accuracy: 0.0000e+00 - val_loss: 0.1812
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1828 - val_accuracy: 0.0000e+00 - val_loss: 0.1938
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.1750 - val_accuracy: 0.0000e+00 - val_loss: 0.2015
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1800 - val_accuracy: 0.0000e+00 - val_loss: 0.1904
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1904 - val_accuracy: 0.0000e+00 - val_loss: 0.1842
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1909 - val_accuracy: 0.0000e+00 - val_loss: 0.1841
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1728 - val_accuracy: 0.0000e+00 - val_loss: 0.1940
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1851 - val_accuracy: 0.0000e+00 - val_loss: 0.2013
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1603 - val_accuracy: 0.0000e+00 - val_loss: 0.2079
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1597 - val_accuracy: 0.0000e+00 - val_loss: 0.2070
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1484 - val_accuracy: 0.0000e+00 - val_loss: 0.1976
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1861 - val_accuracy: 0.0000e+00 - val_loss: 0.1921
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1728 - val_accuracy: 0.0000e+00 - val_loss: 0.1935
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.1723 - val_accuracy: 0.0000e+00 - val_loss: 0.1907

# %% [markdown]
# ## 4. Model Evaluation and Performance Comparison

# %% [markdown]
# Comparing the performance with using R2 and Root Mean Squared Error (RMSE).

# %% [markdown]
# ### 4.1. E. Linear Regression (LR)

# %%
train_predictions = model_lr.predict(X_train)
test_predictions = model_lr.predict(X_test)

r2_train_lr = r2_score(y_train, train_predictions)
r2_test_lr = r2_score(y_test, test_predictions)

rmse_train_lr = mean_squared_error(y_train, train_predictions, squared=False)
rmse_test_lr = mean_squared_error(y_test, test_predictions, squared=False)

print(f"Training R^2: {r2_train_lr:.4f}")
print(f"Test R^2: {r2_test_lr:.4f}")
print(f"Training RMSE: {rmse_train_lr:.4f}")
print(f"Test RMSE: {rmse_test_lr:.4f}")
# Out:
# Training R^2: 0.5675
# Test R^2: 0.4717
# Training RMSE: 5.0024
# Test RMSE: 5.7549

# %% [markdown]
# ### 4.2. E. Random Forest Regressor (RF)

# %%
r2_train_rf = rf_final.score(X=X_train, y=y_train)
r2_test_rf = rf_final.score(X=X_test, y=y_test)

print("R2 on the training data:")
print(r2_train_rf)
print("R2 on the testing data:")
print(r2_test_rf)
# Out:
# R2 on the training data:
# 0.8784204641137269
# R2 on the testing data:
# 0.5507919162841205

# %%
rmse_train_rf = mean_squared_error(y_train, rf_final.predict(X_train), squared=False)
rmse_test_rf = mean_squared_error(y_test, rf_final.predict(X_test), squared=False)

print("RMSE on the training data:")
print(rmse_train_rf)
print("RMSE on the testing data:")
print(rmse_test_rf)
# Out:
# RMSE on the training data:
# 2.652352823674576
# RMSE on the testing data:
# 5.306872460725133

# %%
# Calculate and plot the feature importance of the RF model
imp = rfpimp.importances(rf_final, X_test, y_test)
print(imp)
viz = rfpimp.plot_importances(imp)
viz.view()
# Out:
#                                         Importance
# Feature
# ET                                          0.7113
# LST_NIGHT                                   0.0551
# NDVI                                        0.0427
# PA                                          0.0069
# SMS_PM                                      0.0046
# PAR                                         0.0020
# SAR                                        -0.0002
# SMS_AM                                     -0.0066
# LST_DAY                                    -0.0121

# %% [markdown]
# ### 4.3. E. Gradient Boosting Regressor (XGB)

# %%
model_xgb = XGBRegressor(max_depth=gscv_xgb.best_params_['max_depth'], n_estimators=gscv_xgb.best_params_['n_estimators'], random_state=randomState_xgb)
model_xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=8, n_jobs=None,
#              num_parallel_tree=None, random_state=125, ...)

# %%
# r2_train_xgb, r2_test_xgb, rmse_train_xgb, rmse_test_xgb
r2_train_xgb = model_xgb.score(X=X_train, y=y_train)
r2_test_xgb = model_xgb.score(X=X_test, y=y_test)
rmse_train_xgb = mean_squared_error(y_train, model_xgb.predict(X_train), squared=False)
rmse_test_xgb = mean_squared_error(y_test, model_xgb.predict(X_test), squared=False)

# %%
print("R2 on the training data:")
print(r2_train_xgb)
print("R2 on the testing data:")
print(r2_test_xgb)
# Out:
# R2 on the training data:
# 0.7055894809268239
# R2 on the testing data:
# 0.5503572720233525

# %%
print("RMSE on the training data:")
print(rmse_train_xgb)
print("RMSE on the testing data:")
print(rmse_test_xgb)
# Out:
# RMSE on the training data:
# 4.1274109838493045
# RMSE on the testing data:
# 5.309439248875522

# %%
imp_xgb = rfpimp.importances(model_xgb, X_test, y_test) # permutation
print(imp_xgb)
viz_xgb = rfpimp.plot_importances(imp_xgb)
viz_xgb.view()
# Out:
#                                         Importance
# Feature
# ET                                          0.4905
# LST_NIGHT                                   0.0477
# NDVI                                        0.0447
# SAR                                         0.0129
# SMS_AM                                      0.0073
# PA                                          0.0069
# PAR                                         0.0000
# SMS_PM                                      0.0000
# LST_DAY                                    -0.0130

# %% [markdown]
# ### 4.4. E. Artificial Neural Network (ANN)

# %%
#predictions
y_pred_train_ann = model_ann.predict(X_train).flatten()
y_pred_test_ann = model_ann.predict(X_test).flatten()

#Compute R2 and RMSE
r2_train_ann = np.round(r2_score(y_train, y_pred_train_ann),2)
r2_test_ann = np.round(r2_score(y_test, y_pred_test_ann),2)
rmse_train_ann = np.round(np.sqrt(mean_squared_error(y_train, y_pred_train_ann)),2)
rmse_test_ann = np.round(np.sqrt(mean_squared_error(y_test, y_pred_test_ann)),2)

#print the result
print("Train R2:", r2_train_ann)
print("Test R2:", r2_test_ann)
print("Train RMSE:", rmse_train_ann)
print("Test RMSE:", rmse_test_ann)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train R2: 0.6
# Test R2: 0.43
# Train RMSE: 4.78
# Test RMSE: 5.96

# %%
#crosscheck the y value between real and predicted
crosscheck_y_dict = {
    'y_test' : y_test,
    'y_pred' : np.round(y_pred_test_ann,0),
    'delta' : np.abs(np.round((y_test - y_pred_test_ann),0))
}

#plotting histogram
crosscheck_y_df = pd.DataFrame(crosscheck_y_dict)
plt.hist(crosscheck_y_df['delta'], bins=10)
plt.xlabel(f'Delta\nR2_test = {r2_test_ann}, RMSE_test = {rmse_test_ann}, delta_max = {crosscheck_y_df.delta.max()}')
plt.ylabel('Frequency (Number of Data)')
plt.title(f"Accuracy of ANN Model Based on Delta of Y Test and Y Pred)")
plt.show()

# %% [markdown]
# ### 4.5. Model Performance Comparison

# %%
#please input your metrics in here
metrics_dict = {
    'metrics': ["Train R2","Test R2","Train RMSE","Test RMSE"],
    'LR': [r2_train_lr, r2_test_lr, rmse_train_lr, rmse_test_lr],
    'RF': [r2_train_rf, r2_test_rf, rmse_train_rf, rmse_test_rf],
    'XGB': [r2_train_xgb, r2_test_xgb, rmse_train_xgb, rmse_test_xgb],
    'ANN': [r2_train_ann, r2_test_ann, rmse_train_ann, rmse_test_ann]
}

#create dataframe
metrics_df = pd.DataFrame(metrics_dict)
metrics_df.set_index('metrics')
# Out:
#                                                  LR  \
# metrics
# Train R2                                     0.5675
# Test R2                                      0.4717
# Train RMSE                                   5.0024
# Test RMSE                                    5.7549
#
#                                                  RF  \
# metrics
# Train R2                                     0.8784
# Test R2                                      0.5508
# Train RMSE                                   2.6524
# Test RMSE                                    5.3069
#
#                                                 XGB  \
# metrics
# Train R2                                     0.7056
# Test R2                                      0.5504
# Train RMSE                                   4.1274
# Test RMSE                                    5.3094
#
#                                                 ANN
# metrics
# Train R2                                     0.6000
# Test R2                                      0.4300
# Train RMSE                                   4.7800
# Test RMSE                                    5.9600

# %% [markdown]
# Based on the comparison, it can be said that the best model that can be used for estimating crop yield is []. From this point, [] model would be used for estimation phase (step 5).

# %% [markdown]
# ## 5. Crop Yield Estimation and Export Result
